# %%
dbutils.widgets.text("bronze_location", "", "")
dbutils.widgets.text("concurrency", "", "")
dbutils.widgets.text("date_start", "", "")
dbutils.widgets.text("date_end", "", "")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
bronze_location = dbutils.widgets.get("bronze_location")
concurrency = dbutils.widgets.get("concurrency")
date_start = dbutils.widgets.get("date_start")
date_end = dbutils.widgets.get("date_end")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from datetime import datetime, timedelta
import requests
import math
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType, FloatType, DateType
from pyspark.sql.functions import col, to_date
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
start_date = datetime.strptime(date_start, '%d/%m/%Y')
end_date = datetime.strptime(date_end, '%d/%m/%Y')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
date_range_list = [[start_date+timedelta(days=x)] for x in range((end_date-start_date).days + 1)]

print("Concurrency:",concurrency)
new_concurrency = min([int(concurrency), len(date_range_list)])
print("New Concurrency:", new_concurrency)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Concurrency: 50
# New Concurrency: 50
# </div>

# %%
columns = ["date"]
date_df = spark.createDataFrame(date_range_list, columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(date_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th></tr></thead><tbody><tr><td>2006-04-01T00:00:00.000+0000</td></tr><tr><td>2006-04-02T00:00:00.000+0000</td></tr><tr><td>2006-04-03T00:00:00.000+0000</td></tr><tr><td>2006-04-04T00:00:00.000+0000</td></tr><tr><td>2006-04-05T00:00:00.000+0000</td></tr><tr><td>2006-04-06T00:00:00.000+0000</td></tr><tr><td>2006-04-07T00:00:00.000+0000</td></tr><tr><td>2006-04-08T00:00:00.000+0000</td></tr><tr><td>2006-04-09T00:00:00.000+0000</td></tr><tr><td>2006-04-10T00:00:00.000+0000</td></tr><tr><td>2006-04-11T00:00:00.000+0000</td></tr><tr><td>2006-04-12T00:00:00.000+0000</td></tr><tr><td>2006-04-13T00:00:00.000+0000</td></tr><tr><td>2006-04-14T00:00:00.000+0000</td></tr><tr><td>2006-04-15T00:00:00.000+0000</td></tr><tr><td>2006-04-16T00:00:00.000+0000</td></tr><tr><td>2006-04-17T00:00:00.000+0000</td></tr><tr><td>2006-04-18T00:00:00.000+0000</td></tr><tr><td>2006-04-19T00:00:00.000+0000</td></tr><tr><td>2006-04-20T00:00:00.000+0000</td></tr><tr><td>2006-04-21T00:00:00.000+0000</td></tr><tr><td>2006-04-22T00:00:00.000+0000</td></tr><tr><td>2006-04-23T00:00:00.000+0000</td></tr><tr><td>2006-04-24T00:00:00.000+0000</td></tr><tr><td>2006-04-25T00:00:00.000+0000</td></tr><tr><td>2006-04-26T00:00:00.000+0000</td></tr><tr><td>2006-04-27T00:00:00.000+0000</td></tr><tr><td>2006-04-28T00:00:00.000+0000</td></tr><tr><td>2006-04-29T00:00:00.000+0000</td></tr><tr><td>2006-04-30T00:00:00.000+0000</td></tr><tr><td>2006-05-01T00:00:00.000+0000</td></tr><tr><td>2006-05-02T00:00:00.000+0000</td></tr><tr><td>2006-05-03T00:00:00.000+0000</td></tr><tr><td>2006-05-04T00:00:00.000+0000</td></tr><tr><td>2006-05-05T00:00:00.000+0000</td></tr><tr><td>2006-05-06T00:00:00.000+0000</td></tr><tr><td>2006-05-07T00:00:00.000+0000</td></tr><tr><td>2006-05-08T00:00:00.000+0000</td></tr><tr><td>2006-05-09T00:00:00.000+0000</td></tr><tr><td>2006-05-10T00:00:00.000+0000</td></tr><tr><td>2006-05-11T00:00:00.000+0000</td></tr><tr><td>2006-05-12T00:00:00.000+0000</td></tr><tr><td>2006-05-13T00:00:00.000+0000</td></tr><tr><td>2006-05-14T00:00:00.000+0000</td></tr><tr><td>2006-05-15T00:00:00.000+0000</td></tr><tr><td>2006-05-16T00:00:00.000+0000</td></tr><tr><td>2006-05-17T00:00:00.000+0000</td></tr><tr><td>2006-05-18T00:00:00.000+0000</td></tr><tr><td>2006-05-19T00:00:00.000+0000</td></tr><tr><td>2006-05-20T00:00:00.000+0000</td></tr><tr><td>2006-05-21T00:00:00.000+0000</td></tr><tr><td>2006-05-22T00:00:00.000+0000</td></tr><tr><td>2006-05-23T00:00:00.000+0000</td></tr><tr><td>2006-05-24T00:00:00.000+0000</td></tr><tr><td>2006-05-25T00:00:00.000+0000</td></tr><tr><td>2006-05-26T00:00:00.000+0000</td></tr><tr><td>2006-05-27T00:00:00.000+0000</td></tr><tr><td>2006-05-28T00:00:00.000+0000</td></tr><tr><td>2006-05-29T00:00:00.000+0000</td></tr><tr><td>2006-05-30T00:00:00.000+0000</td></tr><tr><td>2006-05-31T00:00:00.000+0000</td></tr><tr><td>2006-06-01T00:00:00.000+0000</td></tr><tr><td>2006-06-02T00:00:00.000+0000</td></tr><tr><td>2006-06-03T00:00:00.000+0000</td></tr><tr><td>2006-06-04T00:00:00.000+0000</td></tr><tr><td>2006-06-05T00:00:00.000+0000</td></tr><tr><td>2006-06-06T00:00:00.000+0000</td></tr><tr><td>2006-06-07T00:00:00.000+0000</td></tr><tr><td>2006-06-08T00:00:00.000+0000</td></tr><tr><td>2006-06-09T00:00:00.000+0000</td></tr><tr><td>2006-06-10T00:00:00.000+0000</td></tr><tr><td>2006-06-11T00:00:00.000+0000</td></tr><tr><td>2006-06-12T00:00:00.000+0000</td></tr><tr><td>2006-06-13T00:00:00.000+0000</td></tr><tr><td>2006-06-14T00:00:00.000+0000</td></tr><tr><td>2006-06-15T00:00:00.000+0000</td></tr><tr><td>2006-06-16T00:00:00.000+0000</td></tr><tr><td>2006-06-17T00:00:00.000+0000</td></tr><tr><td>2006-06-18T00:00:00.000+0000</td></tr><tr><td>2006-06-19T00:00:00.000+0000</td></tr><tr><td>2006-06-20T00:00:00.000+0000</td></tr><tr><td>2006-06-21T00:00:00.000+0000</td></tr><tr><td>2006-06-22T00:00:00.000+0000</td></tr><tr><td>2006-06-23T00:00:00.000+00 ...

# %%
partitioned_date_df = date_df.repartition(new_concurrency)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def ingest(partitionData):
  #perform heavy initializations like Databse connections
  res = []
  for element in partitionData:
        url = "https://portal.amfiindia.com/DownloadNAVHistoryReport_Po.aspx?frmdt=" + element.date.strftime("%m-%d-%Y")
        x = requests.get(url)
        data = x.text.split("\r\n")
        for line in data:
            if(";" in line ):
                res.append(line.split(";"))
        
        
  return iter(res[1:])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
schema = "Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date".replace("/", "_").replace(" ", "_").split(";")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: [&#39;Scheme_Code&#39;,
#  &#39;Scheme_Name&#39;,
#  &#39;ISIN_Div_Payout_ISIN_Growth&#39;,
#  &#39;ISIN_Div_Reinvestment&#39;,
#  &#39;Net_Asset_Value&#39;,
#  &#39;Repurchase_Price&#39;,
#  &#39;Sale_Price&#39;,
#  &#39;Date&#39;]</div>

# %%
mutualfund_df = partitioned_date_df.rdd.mapPartitions(ingest).toDF(schema)
mutualfund_df = mutualfund_df.filter(col("Scheme_Code") != "Scheme Code")
new_partition = math.ceil(mutualfund_df.count()/10000)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
repartitioned_mfdf = mutualfund_df.repartition(new_partition)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_df = repartitioned_mfdf.withColumn("Scheme_Code", col("Scheme_Code").cast("int")) \
                             .withColumn("Repurchase_Price", col("Repurchase_Price").cast("float")) \
                             .withColumn("Sale_Price", col("Sale_Price").cast("float")) \
                             .withColumn("Date", to_date(col("Date"),"dd-MMM-yyyy"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_df.limit(0).write.format("delta").mode("append").partitionBy("Date").save(bronze_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("CREATE BLOOMFILTER INDEX ON TABLE delta.`{table}` FOR COLUMNS({search_keys} OPTIONS(fpp=0.1, numItems={count}))".format(table=bronze_location, search_keys=",".join(["Scheme_Name"]), count=1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: DataFrame[]</div>

# %%
final_df.write.format("delta").mode("append").partitionBy("Date").save(bronze_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("OPTIMIZE delta.`{table}` ZORDER BY ({search_keys})".format(table=bronze_location, search_keys="Date"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
